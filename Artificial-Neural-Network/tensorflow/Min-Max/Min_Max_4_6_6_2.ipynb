# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\input_layer_4_6_6_2.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:86400,:]
#x_test = input_data[971320:, :]
# Out:
# (86400, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\output_layer_4_6_6_2.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:86400,:]
#y_test = output_data[971320:, :]
print(output_data.shape)
# Out:
# (86400, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(300,input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 400, verbose = 2)
# Out:
# Train on 86400 samples
# Epoch 1/400
# 86400/86400 - 5s - loss: 0.3178 - accuracy: 0.8665
# Epoch 2/400
# 86400/86400 - 5s - loss: 0.2052 - accuracy: 0.9138
# Epoch 3/400
# 86400/86400 - 4s - loss: 0.1901 - accuracy: 0.9170
# Epoch 4/400
# 86400/86400 - 4s - loss: 0.1814 - accuracy: 0.9188
# Epoch 5/400
# 86400/86400 - 4s - loss: 0.1715 - accuracy: 0.9221
# Epoch 6/400
# 86400/86400 - 5s - loss: 0.1615 - accuracy: 0.9254
# Epoch 7/400
# 86400/86400 - 5s - loss: 0.1525 - accuracy: 0.9291
# Epoch 8/400
# 86400/86400 - 5s - loss: 0.1438 - accuracy: 0.9332
# Epoch 9/400
# 86400/86400 - 5s - loss: 0.1358 - accuracy: 0.9369
# Epoch 10/400
# 86400/86400 - 5s - loss: 0.1283 - accuracy: 0.9406
# Epoch 11/400
# 86400/86400 - 4s - loss: 0.1217 - accuracy: 0.9436
# Epoch 12/400
# 86400/86400 - 4s - loss: 0.1166 - accuracy: 0.9459
# Epoch 13/400
# 86400/86400 - 4s - loss: 0.1104 - accuracy: 0.9488
# Epoch 14/400
# 86400/86400 - 5s - loss: 0.1055 - accuracy: 0.9509
# Epoch 15/400
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training Accuracy')
plt.legend()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Min_Max\\Min_Max_4_6_6_2_model.h5')
