# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\input_layer_4_6_5_2.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:7920,:]
#x_test = input_data[971320:, :]
# Out:
# (7920, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\output_layer_4_6_5_2.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:7920,:]
#y_test = output_data[971320:, :]
print(output_data.shape)
# Out:
# (7920, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(200,input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.005)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 1000, verbose = 2)
# Out:
# Train on 7920 samples
# Epoch 1/1000
# 7920/7920 - 1s - loss: 0.4729 - accuracy: 0.7914
# Epoch 2/1000
# 7920/7920 - 0s - loss: 0.3412 - accuracy: 0.8582
# Epoch 3/1000
# 7920/7920 - 0s - loss: 0.2966 - accuracy: 0.8722
# Epoch 4/1000
# 7920/7920 - 0s - loss: 0.2674 - accuracy: 0.8882
# Epoch 5/1000
# 7920/7920 - 0s - loss: 0.2466 - accuracy: 0.8988
# Epoch 6/1000
# 7920/7920 - 0s - loss: 0.2287 - accuracy: 0.9061
# Epoch 7/1000
# 7920/7920 - 0s - loss: 0.2152 - accuracy: 0.9107
# Epoch 8/1000
# 7920/7920 - 0s - loss: 0.2055 - accuracy: 0.9148
# Epoch 9/1000
# 7920/7920 - 0s - loss: 0.1989 - accuracy: 0.9163
# Epoch 10/1000
# 7920/7920 - 0s - loss: 0.1938 - accuracy: 0.9178
# Epoch 11/1000
# 7920/7920 - 0s - loss: 0.1899 - accuracy: 0.9184
# Epoch 12/1000
# 7920/7920 - 0s - loss: 0.1861 - accuracy: 0.9196
# Epoch 13/1000
# 7920/7920 - 0s - loss: 0.1844 - accuracy: 0.9193
# Epoch 14/1000
# 7920/7920 - 0s - loss: 0.1817 - accuracy: 0.9207
# Epoch 15/1000
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training Accuracy')
plt.legend()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Min_Max\\Min_Max_4_6_5_2_model.h5')
