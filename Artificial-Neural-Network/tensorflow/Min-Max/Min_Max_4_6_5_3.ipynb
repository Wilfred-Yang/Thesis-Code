# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\input_layer_4_6_5_3.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:2880,:]
#x_test = input_data[971320:, :]
# Out:
# (2880, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\output_layer_4_6_5_3.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:2880,:]
#y_test = output_data[971320:, :]
print(output_data.shape)
# Out:
# (2880, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(150,input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(150, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.005)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 1000, verbose = 2)
# Out:
# Train on 2880 samples
# Epoch 1/1000
# 2880/2880 - 0s - loss: 0.5211 - accuracy: 0.7696
# Epoch 2/1000
# 2880/2880 - 0s - loss: 0.3885 - accuracy: 0.8356
# Epoch 3/1000
# 2880/2880 - 0s - loss: 0.2944 - accuracy: 0.8843
# Epoch 4/1000
# 2880/2880 - 0s - loss: 0.2459 - accuracy: 0.9136
# Epoch 5/1000
# 2880/2880 - 0s - loss: 0.2127 - accuracy: 0.9160
# Epoch 6/1000
# 2880/2880 - 0s - loss: 0.1976 - accuracy: 0.9194
# Epoch 7/1000
# 2880/2880 - 0s - loss: 0.1907 - accuracy: 0.9187
# Epoch 8/1000
# 2880/2880 - 0s - loss: 0.1861 - accuracy: 0.9203
# Epoch 9/1000
# 2880/2880 - 0s - loss: 0.1831 - accuracy: 0.9221
# Epoch 10/1000
# 2880/2880 - 0s - loss: 0.1812 - accuracy: 0.9205
# Epoch 11/1000
# 2880/2880 - 0s - loss: 0.1792 - accuracy: 0.9209
# Epoch 12/1000
# 2880/2880 - 0s - loss: 0.1786 - accuracy: 0.9222
# Epoch 13/1000
# 2880/2880 - 0s - loss: 0.1779 - accuracy: 0.9214
# Epoch 14/1000
# 2880/2880 - 0s - loss: 0.1761 - accuracy: 0.9221
# Epoch 15/1000
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training Accuracy')
plt.legend()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Min_Max\\Min_Max_4_6_5_3_model.h5')
