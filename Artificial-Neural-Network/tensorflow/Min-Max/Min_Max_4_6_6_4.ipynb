# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\input_layer_4_6_6_4.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:10800,:]
#x_test = input_data[971320:, :]
# Out:
# (10800, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\output_layer_4_6_6_4.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:10800,:]
#y_test = output_data[971320:, :]
print(output_data.shape)
# Out:
# (10800, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(300,input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 500, verbose = 2)
# Out:
# Train on 10800 samples
# Epoch 1/500
# 10800/10800 - 1s - loss: 0.4501 - accuracy: 0.8015
# Epoch 2/500
# 10800/10800 - 1s - loss: 0.2288 - accuracy: 0.9162
# Epoch 3/500
# 10800/10800 - 1s - loss: 0.1917 - accuracy: 0.9164
# Epoch 4/500
# 10800/10800 - 1s - loss: 0.1875 - accuracy: 0.9167
# Epoch 5/500
# 10800/10800 - 1s - loss: 0.1840 - accuracy: 0.9178
# Epoch 6/500
# 10800/10800 - 1s - loss: 0.1811 - accuracy: 0.9185
# Epoch 7/500
# 10800/10800 - 1s - loss: 0.1780 - accuracy: 0.9185
# Epoch 8/500
# 10800/10800 - 1s - loss: 0.1746 - accuracy: 0.9182
# Epoch 9/500
# 10800/10800 - 1s - loss: 0.1718 - accuracy: 0.9175
# Epoch 10/500
# 10800/10800 - 1s - loss: 0.1691 - accuracy: 0.9190
# Epoch 11/500
# 10800/10800 - 1s - loss: 0.1667 - accuracy: 0.9191
# Epoch 12/500
# 10800/10800 - 1s - loss: 0.1644 - accuracy: 0.9205
# Epoch 13/500
# 10800/10800 - 1s - loss: 0.1612 - accuracy: 0.9202
# Epoch 14/500
# 10800/10800 - 1s - loss: 0.1588 - accuracy: 0.9212
# Epoch 15/500
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training Accuracy')
plt.legend()
plt.show()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Min_Max\\Min_Max_4_6_6_4_model.h5')
