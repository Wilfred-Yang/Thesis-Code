# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\input_layer_4_6_4_4.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:36,:]
#x_test = input_data[971320:, :]
# Out:
# (36, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\output_layer_4_6_4_4.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:36,:]
#y_test = output_data[971320:, :]
print(output_data.shape)
# Out:
# (36, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100,input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(100, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.005)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 200, verbose = 2)
# Out:
# Train on 36 samples
# Epoch 1/200
# 36/36 - 1s - loss: 0.7583 - accuracy: 0.4213
# Epoch 2/200
# 36/36 - 0s - loss: 0.6033 - accuracy: 0.6921
# Epoch 3/200
# 36/36 - 0s - loss: 0.4916 - accuracy: 0.8542
# Epoch 4/200
# 36/36 - 0s - loss: 0.4146 - accuracy: 0.8519
# Epoch 5/200
# 36/36 - 0s - loss: 0.3676 - accuracy: 0.8472
# Epoch 6/200
# 36/36 - 0s - loss: 0.3429 - accuracy: 0.8333
# Epoch 7/200
# 36/36 - 0s - loss: 0.3262 - accuracy: 0.8380
# Epoch 8/200
# 36/36 - 0s - loss: 0.3074 - accuracy: 0.8472
# Epoch 9/200
# 36/36 - 0s - loss: 0.2846 - accuracy: 0.8681
# Epoch 10/200
# 36/36 - 0s - loss: 0.2610 - accuracy: 0.9167
# Epoch 11/200
# 36/36 - 0s - loss: 0.2400 - accuracy: 0.9259
# Epoch 12/200
# 36/36 - 0s - loss: 0.2236 - accuracy: 0.9213
# Epoch 13/200
# 36/36 - 0s - loss: 0.2115 - accuracy: 0.9213
# Epoch 14/200
# 36/36 - 0s - loss: 0.2018 - accuracy: 0.9167
# Epoch 15/200
# 36/36 - 0s - loss: 0.1934 - accuracy: 0.9213
# Epoch 16/200
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training Accuracy')
plt.legend()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Min_Max\\Min_Max_4_6_4_4_model.h5')
