# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\input_layer_4_6_4_2.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:756,:]
#x_test = input_data[971320:, :]
# Out:
# (756, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\output_layer_4_6_4_2.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:756,:]
#y_test = output_data[971320:, :]
print(output_data.shape)
# Out:
# (756, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100,input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(100, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.005)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 756, epochs = 1000, verbose = 2)
# Out:
# Train on 756 samples
# Epoch 1/1000
# 756/756 - 1s - loss: 0.8047 - accuracy: 0.3916
# Epoch 2/1000
# 756/756 - 0s - loss: 0.6699 - accuracy: 0.6081
# Epoch 3/1000
# 756/756 - 0s - loss: 0.5757 - accuracy: 0.7600
# Epoch 4/1000
# 756/756 - 0s - loss: 0.5084 - accuracy: 0.8236
# Epoch 5/1000
# 756/756 - 0s - loss: 0.4635 - accuracy: 0.8383
# Epoch 6/1000
# 756/756 - 0s - loss: 0.4399 - accuracy: 0.8381
# Epoch 7/1000
# 756/756 - 0s - loss: 0.4320 - accuracy: 0.8351
# Epoch 8/1000
# 756/756 - 0s - loss: 0.4287 - accuracy: 0.8343
# Epoch 9/1000
# 756/756 - 0s - loss: 0.4208 - accuracy: 0.8333
# Epoch 10/1000
# 756/756 - 0s - loss: 0.4062 - accuracy: 0.8333
# Epoch 11/1000
# 756/756 - 0s - loss: 0.3879 - accuracy: 0.8337
# Epoch 12/1000
# 756/756 - 0s - loss: 0.3700 - accuracy: 0.8350
# Epoch 13/1000
# 756/756 - 0s - loss: 0.3556 - accuracy: 0.8399
# Epoch 14/1000
# 756/756 - 0s - loss: 0.3449 - accuracy: 0.8488
# Epoch 15/1000
# 756/756 - 0s - loss: 0.3366 - accuracy: 0.8634
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training Accuracy')
plt.legend()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Min_Max\\Min_Max_4_6_4_2_model.h5')
