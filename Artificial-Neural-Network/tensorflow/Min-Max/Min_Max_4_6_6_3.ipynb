# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\input_layer_4_6_6_3.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:36000,:]
#x_test = input_data[971320:, :]
# Out:
# (36000, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\output_layer_4_6_6_3.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:36000,:]
#y_test = output_data[971320:, :]
print(output_data.shape)
# Out:
# (36000, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(300,input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 400, verbose = 2)
# Out:
# Train on 36000 samples
# Epoch 1/400
# 36000/36000 - 2s - loss: 0.3181 - accuracy: 0.8726
# Epoch 2/400
# 36000/36000 - 2s - loss: 0.2049 - accuracy: 0.9123
# Epoch 3/400
# 36000/36000 - 2s - loss: 0.1941 - accuracy: 0.9150
# Epoch 4/400
# 36000/36000 - 2s - loss: 0.1883 - accuracy: 0.9154
# Epoch 5/400
# 36000/36000 - 2s - loss: 0.1826 - accuracy: 0.9163
# Epoch 6/400
# 36000/36000 - 2s - loss: 0.1788 - accuracy: 0.9167
# Epoch 7/400
# 36000/36000 - 2s - loss: 0.1748 - accuracy: 0.9175
# Epoch 8/400
# 36000/36000 - 2s - loss: 0.1691 - accuracy: 0.9197
# Epoch 9/400
# 36000/36000 - 2s - loss: 0.1631 - accuracy: 0.9226
# Epoch 10/400
# 36000/36000 - 2s - loss: 0.1571 - accuracy: 0.9261
# Epoch 11/400
# 36000/36000 - 2s - loss: 0.1497 - accuracy: 0.9300
# Epoch 12/400
# 36000/36000 - 2s - loss: 0.1423 - accuracy: 0.9349
# Epoch 13/400
# 36000/36000 - 2s - loss: 0.1354 - accuracy: 0.9386
# Epoch 14/400
# 36000/36000 - 2s - loss: 0.1300 - accuracy: 0.9411
# Epoch 15/400
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training Accuracy')
plt.legend()
plt.show()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Min_Max\\Min_Max_4_6_6_3_model.h5')
