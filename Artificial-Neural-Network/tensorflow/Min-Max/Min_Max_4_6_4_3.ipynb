# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\input_layer_4_6_4_3.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:216,:]
#x_test = input_data[971320:, :]
# Out:
# (216, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Min-Max\\output_layer_4_6_4_3.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:216,:]
#y_test = output_data[971320:, :]
print(output_data.shape)
# Out:
# (216, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100,input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(100, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.005)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 500, verbose = 2)
# Out:
# Train on 216 samples
# Epoch 1/500
# 216/216 - 1s - loss: 0.6781 - accuracy: 0.5876
# Epoch 2/500
# 216/216 - 0s - loss: 0.5582 - accuracy: 0.7894
# Epoch 3/500
# 216/216 - 0s - loss: 0.4739 - accuracy: 0.8322
# Epoch 4/500
# 216/216 - 0s - loss: 0.4196 - accuracy: 0.8445
# Epoch 5/500
# 216/216 - 0s - loss: 0.3900 - accuracy: 0.8414
# Epoch 6/500
# 216/216 - 0s - loss: 0.3727 - accuracy: 0.8399
# Epoch 7/500
# 216/216 - 0s - loss: 0.3551 - accuracy: 0.8395
# Epoch 8/500
# 216/216 - 0s - loss: 0.3323 - accuracy: 0.8457
# Epoch 9/500
# 216/216 - 0s - loss: 0.3060 - accuracy: 0.8746
# Epoch 10/500
# 216/216 - 0s - loss: 0.2808 - accuracy: 0.8981
# Epoch 11/500
# 216/216 - 0s - loss: 0.2597 - accuracy: 0.9132
# Epoch 12/500
# 216/216 - 0s - loss: 0.2437 - accuracy: 0.9167
# Epoch 13/500
# 216/216 - 0s - loss: 0.2321 - accuracy: 0.9190
# Epoch 14/500
# 216/216 - 0s - loss: 0.2227 - accuracy: 0.9201
# Epoch 15/500
# 216/216 - 0s - loss: 0.2139 - accuracy: 0.9236
# Epoch 16/500
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training Accuracy')
plt.legend()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Min_Max\\Min_Max_4_6_4_3_model.h5')
