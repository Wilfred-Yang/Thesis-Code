# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\input_layer_4_6_4_3.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:216,:]
#x_test = input_data[5770840:, :]
# Out:
# (216, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\output_layer_4_6_4_3.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:216,:]
#y_test = output_data[5770840:, :]
print(output_data.shape)
# Out:
# (216, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(100, activation = 'relu'),
    #tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.0035)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 500, verbose = 2)#, validation_data = (x_test, y_test))
# Out:
# Train on 216 samples
# Epoch 1/500
# 216/216 - 1s - loss: 0.7208 - accuracy: 0.4799
# Epoch 2/500
# 216/216 - 0s - loss: 0.6267 - accuracy: 0.6775
# Epoch 3/500
# 216/216 - 0s - loss: 0.5525 - accuracy: 0.7801
# Epoch 4/500
# 216/216 - 0s - loss: 0.4928 - accuracy: 0.8183
# Epoch 5/500
# 216/216 - 0s - loss: 0.4450 - accuracy: 0.8387
# Epoch 6/500
# 216/216 - 0s - loss: 0.4079 - accuracy: 0.8326
# Epoch 7/500
# 216/216 - 0s - loss: 0.3809 - accuracy: 0.8353
# Epoch 8/500
# 216/216 - 0s - loss: 0.3622 - accuracy: 0.8356
# Epoch 9/500
# 216/216 - 0s - loss: 0.3483 - accuracy: 0.8356
# Epoch 10/500
# 216/216 - 0s - loss: 0.3354 - accuracy: 0.8364
# Epoch 11/500
# 216/216 - 0s - loss: 0.3207 - accuracy: 0.8395
# Epoch 12/500
# 216/216 - 0s - loss: 0.3038 - accuracy: 0.8507
# Epoch 13/500
# 216/216 - 0s - loss: 0.2855 - accuracy: 0.8623
# Epoch 14/500
# 216/216 - 0s - loss: 0.2672 - accuracy: 0.8800
# Epoch 15/500
# 216/216 - 0s - loss: 0.2500 - accuracy: 0.8920
# Epoch 16/500
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training and Validating Accuracy')
plt.legend()
plt.show()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Look_ahead_N\\Look_ahead_N_4_6_4_3_model.h5')
