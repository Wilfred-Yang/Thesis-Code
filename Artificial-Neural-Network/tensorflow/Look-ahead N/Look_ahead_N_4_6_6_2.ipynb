# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\input_layer_4_6_6_2.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:86400,:]
#x_test = input_data[5770840:, :]
# Out:
# (86400, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\output_layer_4_6_6_2.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:86400,:]
#y_test = output_data[5770840:, :]
print(output_data.shape)
# Out:
# (86400, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(300, input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(300, activation = 'relu'),
    #tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.005)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 200, verbose = 2)#, validation_data = (x_test, y_test))
# Out:
# Train on 86400 samples
# Epoch 1/200
# 86400/86400 - 3s - loss: 0.2721 - accuracy: 0.8781
# Epoch 2/200
# 86400/86400 - 2s - loss: 0.1903 - accuracy: 0.9100
# Epoch 3/200
# 86400/86400 - 2s - loss: 0.1626 - accuracy: 0.9221
# Epoch 4/200
# 86400/86400 - 2s - loss: 0.1402 - accuracy: 0.9331
# Epoch 5/200
# 86400/86400 - 2s - loss: 0.1208 - accuracy: 0.9438
# Epoch 6/200
# 86400/86400 - 2s - loss: 0.1041 - accuracy: 0.9528
# Epoch 7/200
# 86400/86400 - 2s - loss: 0.0890 - accuracy: 0.9607
# Epoch 8/200
# 86400/86400 - 2s - loss: 0.0781 - accuracy: 0.9664
# Epoch 9/200
# 86400/86400 - 2s - loss: 0.0676 - accuracy: 0.9716
# Epoch 10/200
# 86400/86400 - 2s - loss: 0.0592 - accuracy: 0.9757
# Epoch 11/200
# 86400/86400 - 2s - loss: 0.0519 - accuracy: 0.9790
# Epoch 12/200
# 86400/86400 - 2s - loss: 0.0450 - accuracy: 0.9822
# Epoch 13/200
# 86400/86400 - 2s - loss: 0.0395 - accuracy: 0.9846
# Epoch 14/200
# 86400/86400 - 2s - loss: 0.0343 - accuracy: 0.9869
# Epoch 15/200
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training and Validating Accuracy')
plt.legend()
plt.show()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Look_ahead_N\\Look_ahead_N_4_6_6_2_model.h5')
