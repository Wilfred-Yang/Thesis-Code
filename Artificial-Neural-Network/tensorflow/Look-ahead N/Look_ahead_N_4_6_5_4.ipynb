# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\input_layer_4_6_5_4.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:720,:]
#x_test = input_data[5770840:, :]
# Out:
# (720, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\output_layer_4_6_5_4.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:720,:]
#y_test = output_data[5770840:, :]
print(output_data.shape)
# Out:
# (720, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(70, input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(70, activation = 'relu'),
    #tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.005)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 500, verbose = 2)#, validation_data = (x_test, y_test))
# Out:
# Train on 720 samples
# Epoch 1/500
# 720/720 - 1s - loss: 0.7619 - accuracy: 0.4747
# Epoch 2/500
# 720/720 - 0s - loss: 0.6422 - accuracy: 0.6485
# Epoch 3/500
# 720/720 - 0s - loss: 0.5550 - accuracy: 0.7516
# Epoch 4/500
# 720/720 - 0s - loss: 0.4893 - accuracy: 0.8242
# Epoch 5/500
# 720/720 - 0s - loss: 0.4396 - accuracy: 0.8604
# Epoch 6/500
# 720/720 - 0s - loss: 0.4031 - accuracy: 0.8645
# Epoch 7/500
# 720/720 - 0s - loss: 0.3778 - accuracy: 0.8591
# Epoch 8/500
# 720/720 - 0s - loss: 0.3603 - accuracy: 0.8523
# Epoch 9/500
# 720/720 - 0s - loss: 0.3465 - accuracy: 0.8558
# Epoch 10/500
# 720/720 - 0s - loss: 0.3325 - accuracy: 0.8653
# Epoch 11/500
# 720/720 - 0s - loss: 0.3166 - accuracy: 0.8774
# Epoch 12/500
# 720/720 - 0s - loss: 0.2992 - accuracy: 0.8894
# Epoch 13/500
# 720/720 - 0s - loss: 0.2815 - accuracy: 0.8988
# Epoch 14/500
# 720/720 - 0s - loss: 0.2648 - accuracy: 0.9073
# Epoch 15/500
# 720/720 - 0s - loss: 0.2498 - accuracy: 0.9142
# Epoch 16/500
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training and Validating Accuracy')
plt.legend()
plt.show()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Look_ahead_N\\Look_ahead_N_4_6_5_4_model.h5')
