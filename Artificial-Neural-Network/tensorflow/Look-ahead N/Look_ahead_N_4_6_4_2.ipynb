# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\input_layer_4_6_4_2.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:756,:]
#x_test = input_data[5770840:, :]
# Out:
# (756, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\output_layer_4_6_4_2.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:756,:]
#y_test = output_data[5770840:, :]
print(output_data.shape)
# Out:
# (756, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(100, activation = 'relu'),
    #tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.0035)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 500, verbose = 2)#, validation_data = (x_test, y_test))
# Out:
# Train on 756 samples
# Epoch 1/500
# 756/756 - 1s - loss: 0.6890 - accuracy: 0.5401
# Epoch 2/500
# 756/756 - 0s - loss: 0.5970 - accuracy: 0.7191
# Epoch 3/500
# 756/756 - 0s - loss: 0.5260 - accuracy: 0.8168
# Epoch 4/500
# 756/756 - 0s - loss: 0.4741 - accuracy: 0.8332
# Epoch 5/500
# 756/756 - 0s - loss: 0.4406 - accuracy: 0.8336
# Epoch 6/500
# 756/756 - 0s - loss: 0.4240 - accuracy: 0.8336
# Epoch 7/500
# 756/756 - 0s - loss: 0.4192 - accuracy: 0.8333
# Epoch 8/500
# 756/756 - 0s - loss: 0.4175 - accuracy: 0.8333
# Epoch 9/500
# 756/756 - 0s - loss: 0.4125 - accuracy: 0.8333
# Epoch 10/500
# 756/756 - 0s - loss: 0.4025 - accuracy: 0.8333
# Epoch 11/500
# 756/756 - 0s - loss: 0.3886 - accuracy: 0.8333
# Epoch 12/500
# 756/756 - 0s - loss: 0.3734 - accuracy: 0.8342
# Epoch 13/500
# 756/756 - 0s - loss: 0.3595 - accuracy: 0.8379
# Epoch 14/500
# 756/756 - 0s - loss: 0.3479 - accuracy: 0.8426
# Epoch 15/500
# 756/756 - 0s - loss: 0.3385 - accuracy: 0.8509
# Epoch 16/500
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training and Validating Accuracy')
plt.legend()
plt.show()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Look_ahead_N\\Look_ahead_N_4_6_4_2_model.h5')
