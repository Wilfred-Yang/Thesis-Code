# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\input_layer_4_6_5_2.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:7920,:]
#x_test = input_data[5770840:, :]
# Out:
# (7920, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\output_layer_4_6_5_2.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:7920,:]
#y_test = output_data[5770840:, :]
print(output_data.shape)
# Out:
# (7920, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(150, input_shape = [24], activation = 'relu'),
    tf.keras.layers.Dense(150, activation = 'relu'),
    #tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.005)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 500, verbose = 2)#, validation_data = (x_test, y_test))
# Out:
# Train on 7920 samples
# Epoch 1/500
# 7920/7920 - 1s - loss: 0.4859 - accuracy: 0.7802
# Epoch 2/500
# 7920/7920 - 0s - loss: 0.3399 - accuracy: 0.8591
# Epoch 3/500
# 7920/7920 - 0s - loss: 0.2859 - accuracy: 0.8756
# Epoch 4/500
# 7920/7920 - 0s - loss: 0.2571 - accuracy: 0.8862
# Epoch 5/500
# 7920/7920 - 0s - loss: 0.2376 - accuracy: 0.8941
# Epoch 6/500
# 7920/7920 - 0s - loss: 0.2226 - accuracy: 0.9000
# Epoch 7/500
# 7920/7920 - 0s - loss: 0.2092 - accuracy: 0.9031
# Epoch 8/500
# 7920/7920 - 0s - loss: 0.1983 - accuracy: 0.9059
# Epoch 9/500
# 7920/7920 - 0s - loss: 0.1906 - accuracy: 0.9080
# Epoch 10/500
# 7920/7920 - 0s - loss: 0.1836 - accuracy: 0.9112
# Epoch 11/500
# 7920/7920 - 0s - loss: 0.1780 - accuracy: 0.9126
# Epoch 12/500
# 7920/7920 - 0s - loss: 0.1732 - accuracy: 0.9141
# Epoch 13/500
# 7920/7920 - 0s - loss: 0.1693 - accuracy: 0.9152
# Epoch 14/500
# 7920/7920 - 0s - loss: 0.1667 - accuracy: 0.9172
# Epoch 15/500
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training and Validating Accuracy')
plt.legend()
plt.show()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Look_ahead_N\\Look_ahead_N_4_6_5_2_model.h5')
