# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\input_layer_4_6_3_3.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:12,:]
#x_test = input_data[5770840:, :]
# Out:
# (12, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\output_layer_4_6_3_3.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:12,:]
#y_test = output_data[5770840:, :]
print(output_data.shape)
# Out:
# (12, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(50, input_shape = [24], activation = 'relu'),
    #tf.keras.layers.Dense(200, activation = 'relu'),
    #tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.0035)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 300, verbose = 2)#, validation_data = (x_test, y_test))
# Out:
# Train on 12 samples
# Epoch 1/300
# 12/12 - 1s - loss: 0.7709 - accuracy: 0.4306
# Epoch 2/300
# 12/12 - 0s - loss: 0.7365 - accuracy: 0.4722
# Epoch 3/300
# 12/12 - 0s - loss: 0.7036 - accuracy: 0.5347
# Epoch 4/300
# 12/12 - 0s - loss: 0.6718 - accuracy: 0.5764
# Epoch 5/300
# 12/12 - 0s - loss: 0.6413 - accuracy: 0.6250
# Epoch 6/300
# 12/12 - 0s - loss: 0.6118 - accuracy: 0.6597
# Epoch 7/300
# 12/12 - 0s - loss: 0.5834 - accuracy: 0.7083
# Epoch 8/300
# 12/12 - 0s - loss: 0.5560 - accuracy: 0.7500
# Epoch 9/300
# 12/12 - 0s - loss: 0.5297 - accuracy: 0.7917
# Epoch 10/300
# 12/12 - 0s - loss: 0.5045 - accuracy: 0.8333
# Epoch 11/300
# 12/12 - 0s - loss: 0.4804 - accuracy: 0.8750
# Epoch 12/300
# 12/12 - 0s - loss: 0.4573 - accuracy: 0.8958
# Epoch 13/300
# 12/12 - 0s - loss: 0.4349 - accuracy: 0.9028
# Epoch 14/300
# 12/12 - 0s - loss: 0.4135 - accuracy: 0.9375
# Epoch 15/300
# 12/12 - 0s - loss: 0.3928 - accuracy: 0.9375
# Epoch 16/300
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training and Validating Accuracy')
plt.legend()
plt.show()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Look_ahead_N\\Look_ahead_N_4_6_3_3_model.h5')
