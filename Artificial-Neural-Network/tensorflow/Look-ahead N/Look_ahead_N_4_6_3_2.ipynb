# %%
import tensorflow as tf
import numpy as np
import pickle

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\input_layer_4_6_3_2.pickle','rb') as file:
    input_data = pickle.load(file)
print(input_data.shape)

x_train = input_data[:72,:]
#x_test = input_data[5770840:, :]
# Out:
# (72, 24)

# %%
with open ('C:\\Users\\Wilfred\\Desktop\\Look-ahead-N\\output_layer_4_6_3_2.pickle','rb') as file:
    output_data = pickle.load(file)
output_data = np.transpose(output_data)
y_train = output_data[:72,:]
#y_test = output_data[5770840:, :]
print(output_data.shape)
# Out:
# (72, 12)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(50, input_shape = [24], activation = 'relu'),
    #tf.keras.layers.Dense(200, activation = 'relu'),
    #tf.keras.layers.Dense(200, activation = 'relu'),
    tf.keras.layers.Dense(12, activation = 'sigmoid')
])
adam = tf.keras.optimizers.Adam(lr = 0.0035)
model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x_train, y_train, batch_size = 1024, epochs = 300, verbose = 2)#, validation_data = (x_test, y_test))
# Out:
# Train on 72 samples
# Epoch 1/300
# 72/72 - 0s - loss: 0.7020 - accuracy: 0.5625
# Epoch 2/300
# 72/72 - 0s - loss: 0.6760 - accuracy: 0.6053
# Epoch 3/300
# 72/72 - 0s - loss: 0.6514 - accuracy: 0.6354
# Epoch 4/300
# 72/72 - 0s - loss: 0.6280 - accuracy: 0.6759
# Epoch 5/300
# 72/72 - 0s - loss: 0.6058 - accuracy: 0.7095
# Epoch 6/300
# 72/72 - 0s - loss: 0.5847 - accuracy: 0.7431
# Epoch 7/300
# 72/72 - 0s - loss: 0.5646 - accuracy: 0.7755
# Epoch 8/300
# 72/72 - 0s - loss: 0.5454 - accuracy: 0.8009
# Epoch 9/300
# 72/72 - 0s - loss: 0.5271 - accuracy: 0.8137
# Epoch 10/300
# 72/72 - 0s - loss: 0.5096 - accuracy: 0.8264
# Epoch 11/300
# 72/72 - 0s - loss: 0.4929 - accuracy: 0.8345
# Epoch 12/300
# 72/72 - 0s - loss: 0.4770 - accuracy: 0.8403
# Epoch 13/300
# 72/72 - 0s - loss: 0.4619 - accuracy: 0.8461
# Epoch 14/300
# 72/72 - 0s - loss: 0.4477 - accuracy: 0.8484
# Epoch 15/300
# 72/72 - 0s - loss: 0.4342 - accuracy: 0.8519
# Epoch 16/300
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
acc = history.history['accuracy']
loss = history.history['loss']
#val_acc = history.history['val_accuracy']
#val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#plt.plot(epochs, val_acc, 'b', label = 'Validating accuracy')
plt.title('Training and Validating Accuracy')
plt.legend()
plt.show()

# %%
#model.evaluate(x_test, y_test, verbose = 2)
# Out:
# 5000/1 - 0s - loss: 0.0630 - accuracy: 0.9720
# [0.04715186712741852, 0.9720002]

# %%
model.save('C:\\Users\\Wilfred\\Desktop\\weights\\Look_ahead_N\\Look_ahead_N_4_6_3_2_model.h5')
